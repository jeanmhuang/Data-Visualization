# %% [markdown]
# <a href="https://colab.research.google.com/github/jeanmhuang/Data-Visualization/blob/main/sales_data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas matplotlib seaborn plotly

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Sample sales data (this could be loaded from a CSV in real applications)
data = {
    'Month': ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'],
    'Sales': [2500, 2700, 2200, 3000, 2800, 3500, 4000, 4200, 3700, 3900, 4500, 5000]
}

# Convert to DataFrame
sales_data = pd.DataFrame(data)

# %%
# Line chart for sales over months
plt.figure(figsize=(10, 6))
plt.plot(sales_data['Month'], sales_data['Sales'], marker='o', linestyle='-', color='b')
plt.title('Monthly Sales Performance for the Year')
plt.xlabel('Month')
plt.ylabel('Sales ($)')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Bar chart for monthly sales
plt.figure(figsize=(10, 6))
sns.barplot(x='Month', y='Sales', data=sales_data, palette='Blues_d')
plt.title('Monthly Sales Distribution')
plt.xlabel('Month')
plt.ylabel('Sales ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-11-58bc066a9aa2>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Month', y='Sales', data=sales_data, palette='Blues_d')

# %%
# Pie chart for monthly sales percentage
plt.figure(figsize=(8, 8))
sales_data.set_index('Month')['Sales'].plot.pie(autopct='%1.1f%%', figsize=(8, 8), startangle=90, cmap='Blues')
plt.title('Sales Distribution by Month')
plt.ylabel('')  # Remove y-axis label
plt.show()

# %%
# Interactive Plotly Line Chart
fig = px.line(sales_data, x='Month', y='Sales', title='Monthly Sales Performance', markers=True)
fig.update_layout(xaxis_title='Month', yaxis_title='Sales ($)', xaxis_tickangle=-45)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
